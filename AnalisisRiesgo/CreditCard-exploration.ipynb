# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

credit = pd.read_csv('credit_card_clients.csv', header =1)

credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
# Matriz de correlacion
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
# Covariancia en Pandas
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
import scipy.stats as stats
# Referencia: Seaborn is a Python data visualization library based on matplotlib.
import seaborn as sns 

credit.columns

output = 'default payment next month'

# Exploratory Data Analysis
cols = [ f for f in credit.columns if credit.dtypes[ f ] != "object"]
# Removemos el ID y el default
cols.remove( "ID")
cols.remove( output )

f = pd.melt( credit, id_vars=output, value_vars=cols)
g = sns.FacetGrid( f, hue=output, col="variable", col_wrap=5, sharex=False, sharey=False )
g = g.map( sns.distplot, "value", kde=True).add_legend()

# %%
# Observaciones:
# Default tienen una mayor proporción de valores LIMIT_BAL inferiores
# Los no default tienen una mayor proporción de mujeres (sexo = 2)
# Los no default tienen una mayor proporción de más educados (EDUCATION = 1 o 2)
# Los no default tienen una mayor proporción de solteros (MARRIAGE = 2)
# Los no default tienen una mayor proporción de personas de 30 a 40 años
# Los no default tienen una proporción MUCHO mayor de variables PAY_X cero o negativas 
#    (esto significa que estar al día o adelantarse a los pagos está asociado con no incumplir el mes siguiente). 
#    Esta es una relación fuerte ya que la distribución está más separada, por lo que esperamos que PAY_X sea importante.

# Definimos funcion ChiSquaredTestOfIndependence
#   Descripción: The Chi-Square test of independence es usado para determinar si hay una relación significativa
#   entre dos variables nominales (categóricas). La frecuencia de cada categoría para una variable nominal es comparada
#   a través de las categorias de la segunda variable nominal.

def ChiSquaredTestOfIndependence( df, inputVar, Outcome_Category ):
    # Es de utilidad tener esto en una función. El ChiSquaredTestofIndependence tiene una hipótesis nula: 
    # Outcome_Category es independiente de inputVar. Entonces creamos una estadística de prueba que es una medida de 
    # la diferencia entre "esperado", es decir, lo que observaríamos si Outcome_Category fuera independiente de inputVar
    # y "observado", es decir, lo que realmente muestran los datos. 
    # El valor p devuelto es la probabilidad de ver esta estadística de prueba si la hipótesis nula es verdadera
    Outcome_Category_Table = df.groupby( Outcome_Category )[ Outcome_Category ].count().values
    Outcome_Category_Ratios = Outcome_Category_Table / sum( Outcome_Category_Table )
    possibleVals = df[inputVar].unique()
    observed = []
    expected = []
    for possible in possibleVals:
        countsInCategories = df[ df[ inputVar ] == possible ].groupby( Outcome_Category )[Outcome_Category].count().values
        if( len(countsInCategories) != len( Outcome_Category_Ratios ) ):
            print("Error! La clase " + str( possible) +" de \'" + inputVar + "\' no contiene todos los valores de \'" + Outcome_Category + "\'" )
            return
        elif( min(countsInCategories) < 5 ):
            print("Chi Squared Test necesita por lo menos 5 observaciones en cada celda!")
            print( inputVar + "=" + str(possible) + " tiene insuficientes datos")
            print( countsInCategories )
            return
        else:
            observed.append( countsInCategories )   
            expected.append( Outcome_Category_Ratios * len( df[df[ inputVar ] == possible ]))
    observed = np.array( observed )
    expected = np.array( expected )
    chi_squared_stat = ((observed - expected)**2 / expected).sum().sum()
    degOfF = (observed.shape[0] - 1 ) *(observed.shape[1] - 1 ) 
    
    p_value = 1 - stats.chi2.cdf(x=chi_squared_stat, df=degOfF)
    print("La prueba-estadistica calculada es %.2f" % chi_squared_stat )
    print("Si " + Outcome_Category + " es independiente de " + inputVar + ", este tiene una probabilidad %.2e de ocurrencia" % p_value )

# %%
ChiSquaredTestOfIndependence( credit, "SEX", output )
# Out:
# La prueba-estadistica calculada es 47.91
# Si default payment next month es independiente de SEX, este tiene una probabilidad 4.47e-12 de ocurrencia

# %%
# Ok. "default" no es independiente de "SEX".
ChiSquaredTestOfIndependence( credit, "EDUCATION", output )
# Out:
# Error! La clase 0 de 'EDUCATION' no contiene todos los valores de 'default payment next month'

# %%
# No hay suficientes valores en Education class = 0. Tal vez encontremos lo mismo para los valores de Education = 4, 5, 6.

print("Tenemos %d con EDUCATION=0" % len(credit.loc[ credit["EDUCATION"]==0]))
print("Tenemos %d con EDUCATION=4" % len(credit.loc[ credit["EDUCATION"]==4]))
print("Tenemos %d con EDUCATION=5" % len(credit.loc[ credit["EDUCATION"]==5]))
print("Tenemos %d con EDUCATION=6" % len(credit.loc[ credit["EDUCATION"]==6]))
# Out:
# Tenemos 14 con EDUCATION=0
# Tenemos 123 con EDUCATION=4
# Tenemos 280 con EDUCATION=5
# Tenemos 51 con EDUCATION=6

# %%
# Ya que tenemos mas de 30mil registros, vamos a poner estas instancias no-tipicas de Education dentro de la clase EDUCATION=4 

credit["EDUCATION_Corr"] = credit["EDUCATION"].apply( lambda x: x if ((x>0) and (x<4)) else 4 )
ChiSquaredTestOfIndependence( credit, "EDUCATION_Corr", output ) 
cols.remove("EDUCATION")
cols.append("EDUCATION_Corr")

ChiSquaredTestOfIndependence( credit, "MARRIAGE", output )
# Out:
# La prueba-estadistica calculada es 160.41
# Si default payment next month es independiente de EDUCATION_Corr, este tiene una probabilidad 0.00e+00 de ocurrencia
# La prueba-estadistica calculada es 35.66
# Si default payment next month es independiente de MARRIAGE, este tiene una probabilidad 8.83e-08 de ocurrencia

# %%
# Podemos ver que default no es independiente de EDUCATION_Corr ni independiente de MARRIAGE
# Separamos las variables en cuantitativas y cualitativas


# Variables cuantitativas:
quant = ["LIMIT_BAL", "AGE"]

# Variables cualitativas pero "codificadas" (la mayoría de ellas)
qual_Enc = cols
qual_Enc.remove("LIMIT_BAL")
qual_Enc.remove("AGE")

# %%
# Con las variables PAY_, podemos ver que son importantes pero transformaremos las variables BILL_AMT y PAY_AMT 
# de NT Dollars a Log (NT Dollars)

logged = []
for ii in range(1,7): #rango de las variables es de 1 a 6
    qual_Enc.remove("PAY_AMT" + str( ii ))
    credit[ "log_PAY_AMT" + str( ii )]  = credit["PAY_AMT"  + str( ii )].apply( lambda x: np.log1p(x) if (x>0) else 0 )
    logged.append("log_PAY_AMT" + str( ii ) )

for ii in range(1,7):
    qual_Enc.remove("BILL_AMT" + str( ii ))
    credit[ "log_BILL_AMT" + str( ii )] = credit["BILL_AMT" + str( ii )].apply( lambda x: np.log1p(x) if (x>0) else 0 )
    logged.append("log_BILL_AMT" + str( ii ) )

f = pd.melt( credit, id_vars=output, value_vars=logged)
g = sns.FacetGrid( f, hue=output, col="variable", col_wrap=3, sharex=False, sharey=False )
g = g.map( sns.distplot, "value", kde=True).add_legend()

# %%
# Parece que un registro más alto PAY_AMT está ligeramente asociado con un menor default.

# Entonces ahora tenemos variables cuantitativas, variables qual_Enc y variables logarítmicas. 
# Verifiquemos las correlaciones con la variable de salida:

features = quant + qual_Enc + logged + [output]
corr = credit[features].corr()
plt.subplots(figsize=(30,10))
sns.heatmap( corr, square=True, annot=True, fmt=".1f" )

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 38 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
credit.to_csv("changes.csv", index = None, header=True)

# %%
features = quant + qual_Enc + logged   
X = credit[features].values    
y = credit[ output ].values

# %%
print(features)
# Out:
# ['LIMIT_BAL', 'AGE', 'SEX', 'MARRIAGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'EDUCATION_Corr', 'log_PAY_AMT1', 'log_PAY_AMT2', 'log_PAY_AMT3', 'log_PAY_AMT4', 'log_PAY_AMT5', 'log_PAY_AMT6', 'log_BILL_AMT1', 'log_BILL_AMT2', 'log_BILL_AMT3', 'log_BILL_AMT4', 'log_BILL_AMT5', 'log_BILL_AMT6']
